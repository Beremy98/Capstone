# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from string import ascii_letters
import seaborn as sns

# %%
data = pd.read_csv('Datasets/BootScores.csv')

data.drop(['Unnamed: 1'], axis=1)

#description[['Name', 'Description']]
# Out:
#                         Boot Name  COMFORT  PERFORMANCE  TECH SPECS  \
# 0                 adidas Ace 15.1        9            8           8
# 1        adidas Ace 16+ Primeknit        9            8           8
# 2      adidas Ace 16+ PURECONTROL        6            8           9
# 3       adidas Ace 16.2 Primemesh        5            6           6
# 4                  adidas Ace16.1        6            8           7
# 5       adidas ACE17+ Purecontrol        7            9           9
# 6              adidas adiZero f50        7            9           7
# 7                 adidas Copa17.1        9            8           7
# 8                    adidas Gloro        9            8           6
# 9               adidas Messi 15.1        6            7           7
# 10    Adidas Messi16+ PUREAGILITY        6            9           8
# 11  Adidas Nemeziz 17+ 360Agility        9            9           8
# 12             adidas Nemeziz 18+        7            8           9
# 13             adidas Nemeziz 19+        7            7           8
# 14            adidas Nemeziz 19.1        8            9           8
# 15            adidas Predator 18+        9            8           9
# 16           adidas Predator 18.2        7            6           6
# 17            adidas Predator 19+        9            8           9
# 18           adidas Primeknit 2.0        7            7           9
# 19                  adidas X 15.1        8            7           8
# 20                  adidas X 15.2        8            8           6
# 21                 adidas X15+ SL        6            8           7
# 22          Adidas X16+ PURECHAOS        7            9           8
# 23          adidas X18+ Purespeed        6            7           8
# 24                   adidas X18.1        9            9           9
# 25                    adidas X19+        5            7           8
# 26         Asics DS Light X-FLY K        9            7           6
# 27              Concave Halo+ Pro        8            7           8
# 28                  Concave Volt+        8            7           7
# 29             Concave Volt+ Knit        8            7           9
# ..                            ...      ...          ...         ...
# 34             New Balance Visaro        5            6           6
# 35         New Balance Visaro 2.0        5            6           6
# 36      Nike Elastico Superfly TF        6            7           8
# 37   Nike Hypervenom Phantom 3 DF        8            9           9
# 38     Nike Hypervenom Phantom II        6            8           9
# 39     Nike Hypervenom Phinish II        6            9           8
# 40            Nike Magista Obra 2        9            9           8
# 41      Nike Mercurial Superfly V        7            8           9
# 42   Nike Mercurial Veloce III DF        8            7           7
# 43       Nike Phantom Venom Elite        8            9           8
# 44      Nike Phantom Vision Elite        7            9           8
# 45     Nike Phantom Vision Pro DF        8            9           7
# 46         Nike Superfly360 Elite        6            8           9
# 47           Nike Tiempo Legend 6        9            8           8
# 48           Nike Tiempo Legend 7        9            8           8
# 49             Nike Vapor XII Pro        7            8           6
# 50              Puma evoPOWER 1.2        6            7           8
# 51              Puma evoPOWER 1.3        9            8           8
# 52          Puma evoPOWER Vigor 1        8            9           9
# 53            Puma evoSPEED Fresh        6            7           9
# 54             Puma evoSPEED SL K        7            8           7
# 55             Puma evoSPEED SL-S        7            8           7
# 56              Puma evoTOUCH Pro        5            7           8
# 57               Puma FUTURE 18.1        9            9           8
# 58               Puma King II EF+        6            7           7
# 59          Puma King SL Classico        8            7           6
# 60          Umbro Medusae III Pro        9            8           7
# 61     Under Armour Magnetico Pro        8            9           6
# 62         Under Armour Speedform        9            9           7
# 63         Under Armour Spotlight        8            9           7
#
#     VISUAL EFFECT  CATEGORY SCORE  AVG RETAIL  YEAR
# 0               6               9  8.0   $200    15
# 1               7               8  8.0   $250    16
# 2               8               8  7.8   $300    16
# 3               7               5  5.8   $130    16
# 4               7               8  7.2   $200    16
# 5               8               8  8.2   $300    17
# 6               8               9  8.0   $220    15
# 7               8               9  8.2   $200    17
# 8               8               9  8.0   $110    15
# 9               8               7  7.0   $210    15
# 10              7               8  7.6   $300    16
# 11              7               9  8.4   $320    17
# 12              7               9  8.0   $290    18
# 13              9               7  7.6   $275    19
# 14              8               9  8.4   $225    19
# 15              7               9  8.4   $300    17
# 16              7               6  6.4   $140    18
# 17              8               9  8.5   $275    19
# 18              7               7  7.4   $250    15
# 19              6               9  7.6   $200    15
# 20              6               9  7.4   $110    16
# 21              9               8  7.6   $250    16
# 22              7               8  7.8   $300    16
# 23              7               7  7.0   $280    18
# 24              7               8  8.5   $225    18
# 25              8               6  6.8   $275    19
# 26              7               8  7.4   $215    15
# 27              6               8  7.4   $240    19
# 28              7               7  7.2   $210    17
# 29              6               8  7.6   $250    18
# ..            ...             ...  ...    ...   ...
# 34              8               6  6.2   $180    15
# 35              7               6  6.0   $200    17
# 36              8               7  7.2   $150    15
# 37              7               9  8.4   $300    17
# 38              8               6  7.4   $275    15
# 39              8               9  8.0   $225    16
# 40              7               9  8.4   $300    16
# 41              8               8  8.0   $300    16
# 42              8               9  7.8   $180    17
# 43              9               8  8.4   $250    19
# 44              8               8  7.8   $275    18
# 45              8               7  7.8   $150    19
# 46              7               7  7.4   $275    18
# 47              8               8  8.2   $210    16
# 48              9               8  8.4   $230    17
# 49              7               8  7.2   $120    18
# 50              7               7  7.0   $200    15
# 51              6               9  8.0   $220    16
# 52              7               7  8.0   $220    17
# 53              7               8  7.4   $180    16
# 54              9               8  7.8   $250    16
# 55              7               8  7.4   $200    16
# 56              7               5  6.4   $275    16
# 57              7               8  8.2   $200    18
# 58              6               5  6.2   $200    15
# 59              7               8  7.2   $250    15
# 60              8               9  8.2   $200    19
# 61              8               8  7.8   $220    18
# 62              7               8  8.0   $220    15
# 63              6               8  7.6   $220    16
#
# [64 rows x 9 columns]

# %%
data.describe()
# Out:
#          COMFORT  PERFORMANCE  TECH SPECS  VISUAL EFFECT  CATEGORY SCORE  \
# count  64.000000    64.000000   64.000000      64.000000       64.000000
# mean    7.390625     7.859375    7.625000       7.375000        7.781250
# std     1.292434     0.940570    1.015749       0.845154        1.090635
# min     5.000000     6.000000    6.000000       6.000000        5.000000
# 25%     6.000000     7.000000    7.000000       7.000000        7.000000
# 50%     8.000000     8.000000    8.000000       7.000000        8.000000
# 75%     8.250000     9.000000    8.000000       8.000000        9.000000
# max     9.000000     9.000000    9.000000       9.000000        9.000000
#
#              AVG       YEAR
# count  64.000000  64.000000
# mean    7.603125  16.656250
# std     0.641667   1.335935
# min     5.800000  15.000000
# 25%     7.200000  16.000000
# 50%     7.700000  16.000000
# 75%     8.000000  18.000000
# max     8.500000  19.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 10 columns):
# Boot Name         64 non-null object
# Unnamed: 1        64 non-null object
# COMFORT           64 non-null int64
# PERFORMANCE       64 non-null int64
# TECH SPECS        64 non-null int64
# VISUAL EFFECT     64 non-null int64
# CATEGORY SCORE    64 non-null int64
# AVG               64 non-null float64
# RETAIL            64 non-null object
# YEAR              64 non-null int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 5.1+ KB

# %%
corr = data.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
sns.distplot(data['AVG'], bins=30)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
data['AVG'].value_counts()
# Out:
# 8.0    11
# 7.4     9
# 8.4     7
# 7.8     7
# 7.2     6
# 7.6     6
# 8.2     5
# 7.0     4
# 6.4     2
# 6.2     2
# 8.5     2
# 6.8     1
# 5.8     1
# 6.0     1
# Name: AVG, dtype: int64
